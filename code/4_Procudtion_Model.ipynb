# %% [markdown]
# ## Production model
#
# #### This notebook will find the production model and try our best to increase score on recall by 20%. The best baseline score from AdaBoost is 0.36 x 1.2 = 44%.
#
# #### Game plan
#
# #### 1. Use high correlation features
#
# #### 2. Use grid search on promising model and stack good model
#
# #### 3. Feature engineering features & use one hot encoder
#
#
# ### Best model should beat baseline score and recall > 44%

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
pd.options.display.max_columns = None

# %% [markdown]
# #### Load data & create select features list

# %%
df = pd.read_csv('../data/employee_data_clean_eda.csv')

df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate              Department  \
# 0   41          1               1       1102                   Sales
# 1   49          0               1        279  Research & Development
# 2   37          1               1       1373  Research & Development
# 3   33          0               1       1392  Research & Development
# 4   27          0               1        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  HourlyRate  JobInvolvement  JobLevel                JobRole  \
# 0       0          94               3         2        Sales Executive
# 1       1          61               2         2     Research Scientist
# 2       1          92               2         1  Laboratory Technician
# 3       0          56               3         1     Research Scientist
# 4       1          40               3         1  Laboratory Technician
#
#    JobSatisfaction  MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0                4              0           5993        19479
# 1                2              1           5130        24907
# 2                3              0           2090         2396
# 3                3              1           2909        23159
# 4                2              1           3468        16632
#
#    NumCompaniesWorked  OverTime  PercentSalaryHike  PerformanceRating  \
# 0                   8         1                 11                  3
# 1                   1         0                 23                  4
# 2                   6         1                 15                  3
# 3                   1         1                 11                  3
# 4                   9         0                 12                  3
#
#    RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# 0                         1                 0                  8
# 1                         4                 1                 10
# 2                         2                 0                  7
# 3                         3                 0                  8
# 4                         4                 1                  6
#
#    TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                      0                1               6                   4
# 1                      3                3              10                   7
# 2                      3                3               0                   0
# 3                      3                3               8                   7
# 4                      3                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager  daily_rate_range  \
# 0                        0                     5              1100
# 1                        1                     7               300
# 2                        0                     0              1400
# 3                        3                     0              1400
# 4                        2                     2               600
#
#    salary_range  monthly_rate_range  num_comp_work
# 0          6250               18750            7.5
# 1          6250               21250            2.5
# 2          1250                1250            7.5
# 3          3750               21250            2.5
# 4          3750               16250            7.5

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# /var/folders/yr/lt5kfbcj2vs6bwkkyhxsp_0c0000gn/T/ipykernel_63911/2001914525.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_3edde_row0_col0, #T_3edde_row1_col1, #T_3edde_row2_col2, #T_3edde_row3_col3, #T_3edde_row3_col28, #T_3edde_row4_col4, #T_3edde_row5_col5, #T_3edde_row6_col6, #T_3edde_row7_col7, #T_3edde_row8_col8, #T_3edde_row9_col9, #T_3edde_row10_col10, #T_3edde_row11_col11, #T_3edde_row12_col12, #T_3edde_row13_col13, #T_3edde_row14_col14, #T_3edde_row15_col15, #T_3edde_row16_col16, #T_3edde_row17_col17, #T_3edde_row18_col18, #T_3edde_row19_col19, #T_3edde_row20_col20, #T_3edde_row21_col21, #T_3edde_row22_col22, #T_3edde_row23_col23, #T_3edde_row24_col24, #T_3edde_row25_col25, #T_3edde_row26_col26, #T_3edde_row27_col27, #T_3edde_row28_col3, #T_3edde_row28_col28, #T_3edde_row29_col29, #T_3edde_row30_col30, #T_3edde_row31_col31 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3edde_row0_col1, #T_3edde_row0_col7, #T_3edde_row2_col18, #T_3edde_row13_col17, #T_3edde_row13_col18, #T_3edde_row15_col4, #T_3edde_row15_col22, #T_3edde_row16_col5, #T_3edde_row17_col2, #T_3edde_row22_col18, #T_3edde_row23_col3, #T_3edde_row23_col28, #T_3edde_row24_col30, #T_3edde_row25_col1, #T_3edde_row29_col7, #T_3edde_row29_col17, #T_3edde_row29_col18, #T_3edde_row30_col5, #T_3edde_row31_col22 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_3edde_row0_
{
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_3edde_row0_col20, #T_3edde_row2_col10

# %%
corr = df.corr()[['Attrition']].sort_values(by='Attrition', ascending=False)

corr.style.background_gradient(cmap='coolwarm').set_precision(2) 
# Got how to do precision from: https://stackoverflow.com/questions/29432629/plot-correlation-matrix-using-pandas
# Out:
# /var/folders/yr/lt5kfbcj2vs6bwkkyhxsp_0c0000gn/T/ipykernel_63911/3675511486.py:3: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_c7346_row0_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c7346_row1_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_c7346_row2_col0, #T_c7346_row3_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_c7346_row4_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_c7346_row5_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_c7346_row6_col0 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_c7346_row7_col0 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_c7346_row8_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_c7346_row9_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_c7346_row10_col0 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_c7346_row11_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_c7346_row12_col0 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_c7346_row13_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_c7346_row14_col0 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_c7346_row15_col0, #T_c7346_row16_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_c7346_row17_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_c7346_row18_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_c7346_row19_col0 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_c7346_row20_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_c7346_row21_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_c7346_row22_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_c7346_row23_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_c7346_row24_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_c7346_row25_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_c7346_row26_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_c7346_row27_col0, #T_c7346_row28_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_c7346_row29_col0, #T_c7346_row30_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_c7346_row31_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c7346">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7346_level0_col0" class="col_heading level0 col0" >Attrition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7346_level0_row0" class="row_heading level0 row0" >Attrition</th>
#       <td id="T_c7346_row0_col0" class="data row0 col0" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row1" class="row_heading level0 row1" >OverTime</th>
#       <td id="T_c7346_row1_col0" class="data row1 col0" >0.25</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row2" class="row_heading level0 row2" >DistanceFromHome</th>
#       <td id="T_c7346_row2_col0" class="data row2 col0" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row3" class="row_heading level0 row3" >num_comp_work</th>
#       <td id="T_c7346_row3_col0" class="data row3 col0" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row4" class="row_heading level0 row4" >BusinessTravel</th>
#       <td id="T_c7346_row4_col0" class="data row4 col0" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row5" class="row_heading level0 row5" >NumCompaniesWorked</th>
#       <td id="T_c7346_row5_col0" class="data row5 col0" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row6" class="row_heading level0 row6" >Gender</th>
#       <td id="T_c7346_row6_col0" class="data row6 col0" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row7" class="row_heading level0 row7" >MonthlyRate</th>
#       <td id="T_c7346_row7_col0" class="data row7 col0" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row8" class="row_heading level0 row8" >monthly_rate_range</th>
#       <td id="T_c7346_row8_col0" class="data row8 col0" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row9" class="row_heading level0 row9" >PerformanceRating</th>
#       <td id="T_c7346_row9_col0" class="data row9 col0" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row10" class="row_heading level0 row10" >HourlyRate</th>
#       <td id="T_c7346_row10_col0" class="data row10 col0" >-0.01</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row11" class="row_heading level0 row11" >PercentSalaryHike</th>
#       <td id="T_c7346_row11_col0" class="data row11 col0" >-0.01</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row12" class="row_heading level0 row12" >Education</th>
#       <td id="T_c7346_row12_col0" class="data row12 col0" >-0.03</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row13" class="row_heading level0 row13" >YearsSinceLastPromotion</th>
#       <td id="T_c7346_row13_col0" class="data row13 col0" >-0.04</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row14" class="row_heading level0 row14" >RelationshipSatisfaction</th>
#       <td id="T_c7346_row14_col0" class="data row14 col0" >-0.05</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row15" class="row_heading level0 row15" >daily_rate_range</th>
#       <td id="T_c7346_row15_col0" class="data row15 col0" >-0.05</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row16" class="row_heading level0 row16" >DailyRate</th>
#       <td id="T_c7346_row16_col0" class="data row16 col0" >-0.05</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row17" class="row_heading level0 row17" >TrainingTimesLastYear</th>
#       <td id="T_c7346_row17_col0" class="data row17 col0" >-0.06</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row18" class="row_heading level0 row18" >WorkLifeBalance</th>
#       <td id="T_c7346_row18_col0" class="data row18 col0" >-0.06</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row19" class="row_heading level0 row19" >MaritalStatus</th>
#       <td id="T_c7346_row19_col0" class="data row19 col0" >-0.09</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row20" class="row_heading level0 row20" >JobSatisfaction</th>
#       <td id="T_c7346_row20_col0" class="data row20 col0" >-0.10</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row21" class="row_heading level0 row21" >EnvironmentSatisfaction</th>
#       <td id="T_c7346_row21_col0" class="data row21 col0" >-0.11</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row22" class="row_heading level0 row22" >JobInvolvement</th>
#       <td id="T_c7346_row22_col0" class="data row22 col0" >-0.13</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row23" class="row_heading level0 row23" >StockOptionLevel</th>
#       <td id="T_c7346_row23_col0" class="data row23 col0" >-0.14</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row24" class="row_heading level0 row24" >YearsAtCompany</th>
#       <td id="T_c7346_row24_col0" class="data row24 col0" >-0.15</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row25" class="row_heading level0 row25" >YearsWithCurrManager</th>
#       <td id="T_c7346_row25_col0" class="data row25 col0" >-0.16</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row26" class="row_heading level0 row26" >MonthlyIncome</th>
#       <td id="T_c7346_row26_col0" class="data row26 col0" >-0.17</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row27" class="row_heading level0 row27" >Age</th>
#       <td id="T_c7346_row27_col0" class="data row27 col0" >-0.17</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row28" class="row_heading level0 row28" >YearsInCurrentRole</th>
#       <td id="T_c7346_row28_col0" class="data row28 col0" >-0.17</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row29" class="row_heading level0 row29" >salary_range</th>
#       <td id="T_c7346_row29_col0" class="data row29 col0" >-0.17</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row30" class="row_heading level0 row30" >JobLevel</th>
#       <td id="T_c7346_row30_col0" class="data row30 col0" >-0.18</td>
#     </tr>
#     <tr>
#       <th id="T_c7346_level0_row31" class="row_heading level0 row31" >TotalWorkingYears</th>
#       <td id="T_c7346_row31_col0" class="data row31 col0" >-0.18</td>
#     </tr>
#   </tbody>
# </tabl

# %%
# select one that correlation over +/- 10%
selected_features = [
    'Age',
    'BusinessTravel',
    'Department',
    'DistanceFromHome',
    'EducationField',
    'EnvironmentSatisfaction',
    'JobInvolvement',
    'JobLevel',
    'JobRole', # category
    'JobSatisfaction',
    'MaritalStatus',
    'salary_range', # will test between MonthlyIncome
    'NumCompaniesWorked',
    'num_comp_work',
    'OverTime', # (*****+25%)
    'RelationshipSatisfaction',
    'StockOptionLevel',
    'TotalWorkingYears', # (****-18%)
    'TrainingTimesLastYear',
    'WorkLifeBalance', # (****4)
    'YearsAtCompany',
    'YearsInCurrentRole',
    'YearsWithCurrManager'
]

# %%
df[selected_features].columns
# Out:
# Index(['Age', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'EducationField', 'EnvironmentSatisfaction', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'salary_range', 'NumCompaniesWorked', 'num_comp_work', 'OverTime',
#        'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# #### Train Test Split

# %%
X = df[selected_features]
y = df['Attrition']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y, test_size=0.15)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1247, 23), (221, 23), (1247,), (221,))

# %% [markdown]
# ### Create Dummies

# %% [markdown]
# #### - List all object columns

# %%
# Check all object categories
glimpse = []
for c in df.columns:
    make_set = list(set(df[c]))
    data = {'column_name':c, 'set_10':make_set[:10], 'set_count':len(make_set), 'type':str(df[c].dtypes)}
    #glimpse.append(data)
    if data['type'] == 'object':
        glimpse.append(data)
df_glimpse = pd.DataFrame(glimpse)
df_glimpse
# Out:
#       column_name                                             set_10  \
# 0      Department   [Sales, Research & Development, Human Resources]
# 1  EducationField  [Life Sciences, Technical Degree, Marketing, O...
# 2         JobRole  [Sales Executive, Research Director, Research ...
#
#    set_count    type
# 0          3  object
# 1          6  object
# 2          9  object

# %%
dummy_col = [c for c in df_glimpse['column_name'] if c in selected_features]

dummy_col
# Out:
# ['Department', 'EducationField', 'JobRole']

# %%
X_train_dum = pd.get_dummies(X_train, columns=dummy_col) # drop_first=True increase train score but drop the test score
X_test_dum = pd.get_dummies(X_test, columns=dummy_col) # drop_first=True increase train score but drop the test score

X_train_dum.shape, X_test_dum.shape
# Out:
# ((1247, 38), (221, 38))

# %% [markdown]
# #### Modeling with dummies

# %%
# function for iterate models
def model_processing(model, X_train, X_test, y_train, y_test):
    scores = []
    cm_train = []
    cm_test = []
    for m in model:
        m.fit(X_train, y_train)
        model_name = type(m).__name__
        scores.append([model_name, m.score(X_train, y_train), m.score(X_test, y_test)])
        
        cm_train.append([model_name, confusion_matrix(y_train, m.predict(X_train))])
        cm_test.append([model_name, confusion_matrix(y_test, m.predict(X_test))])
    return scores, cm_train, cm_test
# Got how to get model name from: https://stackoverflow.com/questions/52763325/how-to-obtain-only-the-name-of-a-models-object-in-scikitlearn

# %%
# function to print confusion matrix scores
def print_score(cm, is_print=False):
    tn, fp, fn, tp = cm.ravel()
    # calculate accuracy
    conf_accuracy = (float (tp+tn) / float(tp + tn + fp + fn))
    
    # calculate the recall
    conf_recall = (tp / float(tp + fn))

    if is_print:
        decimal = 3
        print(f'Accuracy: \t{round(conf_accuracy,decimal)}') 
        print(f'Recall: \t{round(conf_recall,decimal)}') 
    return conf_accuracy, conf_recall

# %%
def confusion_matrix_score(cm, is_print=False):
    cm_scores = []
    for c in cm:
        tn, fp, fn, tp = c[1].ravel()
        acc = (float (tp+tn) / float(tp + tn + fp + fn))
        rcl = (tp / float(tp + fn))
        if is_print:
            print(c[0], ': Accuracy =', acc, ', Recall =', rcl)
        cm_scores.append([c[0], acc, rcl, tn, fp, fn, tp])
    return cm_scores

# %%
# process all models - DUMMY
lr = LogisticRegression(random_state=42)
rf = RandomForestClassifier(random_state=42)
ada = AdaBoostClassifier(random_state=42)
knn = KNeighborsClassifier()
model = [lr, rf, ada, knn]
scores, cm_train, cm_test = model_processing(model, X_train_dum, X_test_dum, y_train, y_test)
# Out:
# /Users/atigon/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/atigon/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/atigon/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/atigon/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/atigon/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
pd.DataFrame(scores, columns=['model', 'train_score', 'test_score'])
# Out:
#                     model  train_score  test_score
# 0      LogisticRegression     0.844427    0.855204
# 1  RandomForestClassifier     1.000000    0.850679
# 2      AdaBoostClassifier     0.901363    0.873303
# 3    KNeighborsClassifier     0.874900    0.832579

# %%
cm_scores_train = confusion_matrix_score(cm_train)

df_cm_train = pd.DataFrame(cm_scores_train, columns=['model', 'train_accuracy', 'train_recall', 'tn', 'fp', 'fn', 'tp'])
df_cm_train.to_csv('../data/cm_scores_train.csv', index=False)
df_cm_train
# Out:
#                     model  train_accuracy  train_recall    tn  fp   fn   tp
# 0      LogisticRegression        0.844427         0.060  1041   6  188   12
# 1  RandomForestClassifier        1.000000         1.000  1047   0    0  200
# 2      AdaBoostClassifier        0.901363         0.470  1030  17  106   94
# 3    KNeighborsClassifier        0.874900         0.305  1030  17  139   61

# %%
cm_scores_test = confusion_matrix_score(cm_test)

df_cm_test = pd.DataFrame(cm_scores_test, columns=['model', 'test_accuracy', 'test_recall', 'tn', 'fp', 'fn', 'tp'])
df_cm_test.to_csv('../data/cm_scores_test.csv', index=False)
df_cm_test
# Out:
#                     model  test_accuracy  test_recall   tn  fp  fn  tp
# 0      LogisticRegression       0.855204     0.085714  186   0  32   3
# 1  RandomForestClassifier       0.850679     0.142857  183   3  30   5
# 2      AdaBoostClassifier       0.873303     0.428571  178   8  20  15
# 3    KNeighborsClassifier       0.832579     0.142857  179   7  30   5

# %% [markdown]
# #### Until now, if we look at AdaBoostClassifier, our model better that baseline 0.429/0.361 = 1.19 or 19%, close to goal we aim at 20%
# ##### Next, we'll try OneHotEncoder and StandardScaler to see if the score improve
# ##### Then We'll skip to working on Streamlit then after that we'll go back to do some hypertuning to see if the score can be improve.

# %% [markdown]
# #### OneHotEncoder

# %%
ohe = OneHotEncoder(sparse=True, handle_unknown='ignore')
X_train_ohe = ohe.fit_transform(X_train)
X_test_ohe = ohe.transform(X_test)

X_train_enc.shape, X_test_enc.shape
# Out:
# ((1247, 264), (221, 264))

# %%
# process all models - OHE
lr = LogisticRegression(random_state=42)
rf = RandomForestClassifier(random_state=42)
ada = AdaBoostClassifier(random_state=42)
knn = KNeighborsClassifier()
model = [lr, rf, ada, knn]
scores, cm_train, cm_test = model_processing(model, X_train_ohe, X_test_ohe, y_train, y_test)
# Out:
# /Users/atigon/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/atigon/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/atigon/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/atigon/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
pd.DataFrame(scores, columns=['model', 'train_score', 'test_score'])
# Out:
#                     model  train_score  test_score
# 0      LogisticRegression     0.921411    0.850679
# 1  RandomForestClassifier     1.000000    0.868778
# 2      AdaBoostClassifier     0.896552    0.864253
# 3    KNeighborsClassifier     0.887731    0.832579

# %%
cm_scores_train = confusion_matrix_score(cm_train)

df_cm_train = pd.DataFrame(cm_scores_train, columns=['model', 'train_accuracy', 'train_recall', 'tn', 'fp', 'fn', 'tp'])
df_cm_train.to_csv('../data/cm_scores_train.csv', index=False)
df_cm_train
# Out:
#                     model  train_accuracy  train_recall    tn  fp   fn   tp
# 0      LogisticRegression        0.921411         0.590  1031  16   82  118
# 1  RandomForestClassifier        1.000000         1.000  1047   0    0  200
# 2      AdaBoostClassifier        0.896552         0.485  1021  26  103   97
# 3    KNeighborsClassifier        0.887731         0.375  1032  15  125   75

# %%
cm_scores_test = confusion_matrix_score(cm_test)

df_cm_test = pd.DataFrame(cm_scores_test, columns=['model', 'test_accuracy', 'test_recall', 'tn', 'fp', 'fn', 'tp'])
df_cm_test.to_csv('../data/cm_scores_test.csv', index=False)
df_cm_test
# Out:
#                     model  test_accuracy  test_recall   tn  fp  fn  tp
# 0      LogisticRegression       0.850679     0.428571  173  13  20  15
# 1  RandomForestClassifier       0.868778     0.200000  185   1  28   7
# 2      AdaBoostClassifier       0.864253     0.428571  176  10  20  15
# 3    KNeighborsClassifier       0.832579     0.200000  177   9  28   7

# %% [markdown]
# #### StandardScaler + OHE

# %%
# https://stackoverflow.com/questions/38420847/apply-standardscaler-to-parts-of-a-data-set

# %%
len(selected_features)
# Out:
# 23

# %%
numerical_features = [c for c in selected_features if c not in dummy_col]

len(numerical_features)
# Out:
# 20

# %%
ct = ColumnTransformer([
        ('sc', StandardScaler(), numerical_features),
        ('ohe', OneHotEncoder(), dummy_col)
    ], remainder='passthrough')

X_train_ct = ct.fit_transform(X_train[selected_features])
X_test_ct = ct.transform(X_test[selected_features])
X_train_ct.shape, X_test_ct.shape
# Out:
# ((1247, 38), (221, 38))

# %%
# process all models - CT(SC,OHE)
lr = LogisticRegression(random_state=42)
rf = RandomForestClassifier(random_state=42)
ada = AdaBoostClassifier(random_state=42)
knn = KNeighborsClassifier()
model = [lr, rf, ada, knn]
scores, cm_train, cm_test = model_processing(model, X_train_ct, X_test_ct, y_train, y_test)
# Out:
# /Users/atigon/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/atigon/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/atigon/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/atigon/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# /Users/atigon/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
pd.DataFrame(scores, columns=['model', 'train_score', 'test_score'])
# Out:
#                     model  train_score  test_score
# 0      LogisticRegression     0.841219    0.855204
# 1  RandomForestClassifier     1.000000    0.850679
# 2      AdaBoostClassifier     0.901363    0.873303
# 3    KNeighborsClassifier     0.874900    0.832579

# %%
cm_scores_train = confusion_matrix_score(cm_train)

df_cm_train = pd.DataFrame(cm_scores_train, columns=['model', 'train_accuracy', 'train_recall', 'tn', 'fp', 'fn', 'tp'])
df_cm_train.to_csv('../data/cm_scores_train.csv', index=False)
df_cm_train
# Out:
#                     model  train_accuracy  train_recall    tn  fp   fn   tp
# 0      LogisticRegression        0.841219         0.035  1042   5  193    7
# 1  RandomForestClassifier        1.000000         1.000  1047   0    0  200
# 2      AdaBoostClassifier        0.901363         0.470  1030  17  106   94
# 3    KNeighborsClassifier        0.874900         0.305  1030  17  139   61

# %%
cm_scores_test = confusion_matrix_score(cm_test)

df_cm_test = pd.DataFrame(cm_scores_test, columns=['model', 'test_accuracy', 'test_recall', 'tn', 'fp', 'fn', 'tp'])
df_cm_test.to_csv('../data/cm_scores_test.csv', index=False)
df_cm_test
# Out:
#                     model  test_accuracy  test_recall   tn  fp  fn  tp
# 0      LogisticRegression       0.855204     0.085714  186   0  32   3
# 1  RandomForestClassifier       0.850679     0.142857  183   3  30   5
# 2      AdaBoostClassifier       0.873303     0.428571  178   8  20  15
# 3    KNeighborsClassifier       0.832579     0.142857  179   7  30   5

# %% [markdown]
# #### Try XGBoost

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
model = [xgb]
scores, cm_train, cm_test = model_processing(model, X_train_ct, X_test_ct, y_train, y_test)
cm_scores_test = confusion_matrix_score(cm_test)
cm_scores_train = confusion_matrix_score(cm_train)

pd.DataFrame(scores, columns=['model', 'train_score', 'test_score'])
# Out:
#            model  train_score  test_score
# 0  XGBClassifier          1.0    0.864253

# %%
df_cm_train = pd.DataFrame(cm_scores_train, columns=['model', 'train_accuracy', 'train_recall', 'tn', 'fp', 'fn', 'tp'])
df_cm_train.to_csv('../data/cm_scores_train.csv', index=False)
df_cm_train
# Out:
#            model  train_accuracy  train_recall    tn  fp  fn   tp
# 0  XGBClassifier             1.0           1.0  1047   0   0  200

# %%
df_cm_test = pd.DataFrame(cm_scores_test, columns=['model', 'test_accuracy', 'test_recall', 'tn', 'fp', 'fn', 'tp'])
df_cm_test.to_csv('../data/cm_scores_test.csv', index=False)
df_cm_test
# Out:
#            model  test_accuracy  test_recall   tn  fp  fn  tp
# 0  XGBClassifier       0.864253     0.371429  178   8  22  13

# %% [markdown]
# #### Basic Stack

# %% [markdown]
# #### If have time, working on precision TP/(TP+FP)

# %% [markdown]
# #### Skip hyper_tuning to working on streamlit_app
